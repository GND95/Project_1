# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import sys
import os

# %%
#read the data sets
csv_path = "Resources/data.csv"
music_df = pd.read_csv(csv_path)

# %%
csv_path = "Resources/data_w_genres.csv"
genre_df = pd.read_csv(csv_path)

# %%
#checking if a random artist is on both data sets
genre_df.loc[(genre_df["artists"] == "Louis Armstrong")]
# Out:
#                                                   genres          artists  \
# 15222  ['adult standards', 'dixieland', 'harlem renai...  Louis Armstrong
#
#        acousticness  danceability    duration_ms    energy  instrumentalness  \
# 15222      0.790156      0.547011  230558.994728  0.289108          0.088578
#
#        liveness   loudness  speechiness       tempo   valence  popularity  \
# 15222  0.273495 -12.883371     0.098098  111.638654  0.531922   20.652021
#
#        key  mode  count
# 15222    0     1    569

# %%
#clean the "artists" column in order to merge the two data sets for further analysis
spec_chars = ["[","]",'"',"'"]
for char in spec_chars:
    music_df['artists'] = music_df['artists'].str.replace(char, '')

# %%
merge_genre = music_df.merge(genre_df,on=["artists"],how = "left")
merge_genre.head(20)
# Out:
#     valence_x  year  acousticness_x  \
# 0      0.0594  1921          0.9820
# 1      0.9630  1921          0.7320
# 2      0.0394  1921          0.9610
# 3      0.1650  1921          0.9670
# 4      0.2530  1921          0.9570
# 5      0.1960  1921          0.5790
# 6      0.4060  1921          0.9960
# 7      0.0731  1921          0.9930
# 8      0.7210  1921          0.9960
# 9      0.7710  1921          0.9820
# 10     0.8260  1921          0.9950
# 11     0.5780  1921          0.9940
# 12     0.4930  1921          0.9900
# 13     0.2120  1921          0.9120
# 14     0.4930  1921          0.0175
# 15     0.2820  1921          0.9890
# 16     0.2180  1921          0.9570
# 17     0.6640  1921          0.9960
# 18     0.0778  1921          0.1480
# 19     0.5270  1921          0.9710
#
#                                               artists  danceability_x  \
# 0   Sergei Rachmaninoff, James Levine, Berliner Ph...           0.279
# 1                                          Dennis Day           0.819
# 2   KHP Kridhamardawa Karaton Ngayogyakarta Hadini...           0.328
# 3                                        Frank Parker           0.275
# 4                                          Phil Regan           0.418
# 5   KHP Kridhamardawa Karaton Ngayogyakarta Hadini...           0.697
# 6                                      John McCormack           0.518
# 7                                 Sergei Rachmaninoff           0.389
# 8                                     Ignacio Corsini           0.485
# 9                                             Fortugé           0.684
# 10                                  Maurice Chevalier           0.463
# 11                                    Ignacio Corsini           0.378
# 12                                            Georgel           0.315
# 13                                    Mehmet Kemiksiz           0.415
# 14                                         Zay Gatsby           0.527
# 15                   Sergei Rachmaninoff, Ruth Laredo           0.384
# 16                                         Phil Regan           0.259
# 17                   Hector Berlioz, Arturo Toscanini           0.541
# 18                                            THE GUY           0.604
# 19                                  Christopher Lynch           0.540
#
#     duration_ms_x  energy_x  explicit                      id  \
# 0          831667    0.2110         0  4BJqT0PrAfrxzMOxytFOIz
# 1          180533    0.3410         0  7xPhfUan2yNtyFG0cUWkt8
# 2          500062    0.1660         0  1o6I8BglA6ylDMrIELygv1
# 3          210000    0.3090         0  3ftBPsC5vPBKxYSee08FDH
# 4          166693    0.1930         0  4d6HGyGT8e121BsdKmw9v6
# 5          395076    0.3460         0  4pyw9DVHGStUre4J6hPngr
# 6          159507    0.2030         0  5uNZnElqOS3W4fRmRYPk4T
# 7          218773    0.0880         0  02GDntOXexBFUvSgaXLPkd
# 8          161520    0.1300         0  05xDjWH9ub67nJJk82yfGf
# 9          196560    0.2570         0  08zfJvRLp7pjAb94MA9JmF
# 10         147133    0.2600         0  0BMkRpQtDoKjcgzCpnqLNa
# 11         155413    0.1150         0  0F30WM8qRpO8kdolepZqdM
# 12         190800    0.3630         0  0H3k2CvJvHULnWChlbeFgx
# 13         184973    0.4200         0  0LcXzABeA84EgudqpNUN1I
# 14         205072    0.6910         1  0MJZ4hh60zwsYleWWxT5yW
# 15         221013    0.1710         0  0NFeJgmTAV1kDfzSQNK41Z
# 16         186467    0.2120         0  0Nk5f07H3JaEunGrYfbqHM
# 17         250747    0.2830         0  0POO8XaUgW5Qjbv9sbDy8W
# 18         204957    0.4180         1  0QQmUf4aPFaN9U2yRko595
# 19         122000    0.0848         0  0QU5xT6Mik4vpyt1ItsRXK
#
#     instrumentalness_x  ...  instrumentalness_y  liveness_y  loudness_y  \
# 0             0.878000  ...                 NaN         NaN         NaN
# 1             0.000000  ...        1.970000e-06    0.259680  -11.580400
# 2             0.913000  ...        4.987357e-01    0.148443  -17.178000
# 3             0.000028  ...        2.770000e-05    0.381000   -9.316000
# 4             0.000002  ...        2.158933e-04    0.195000  -11.083000
# 5             0.168000  ...        4.987357e-01    0.148443  -17.178000
# 6             0.000000  ...        1.060000e-05    0.107400  -13.036000
# 7             0.527000  ...        7.933563e-01    0.236443  -20.485082
# 8             0.151000  ...        4.251591e-01    0.182707  -20.862591
# 9             0.000000  ...        1.550000e-07    0.391875  -15.481875
# 10            0.000000  ...        8.749380e-03    0.244064  -14.398738
# 11            0.906000  ...        4.251591e-01    0.182707  -20.862591
# 12            0.000000  ...        0.000000e+00    0.292000  -12.562000
# 13            0.890000  ...        1.154437e-01    0.195907   -8.267429
# 14            0.384000  ...        3.840000e-01    0.358000   -7.298000
# 15            0.820000  ...                 NaN         NaN         NaN
# 16            0.000222  ...        2.158933e-04    0.195000  -11.083000
# 17            0.898000  ...                 NaN         NaN         NaN
# 18            0.038200  ...        1.413167e-01    0.149883  -11.733833
# 19            0.001960  ...        3.978080e-04    0.129740  -14.801600
#
#     speechiness_y     tempo_y  valence_y popularity_y  key_y  mode_y   count
# 0             NaN         NaN        NaN          NaN    NaN     NaN     NaN
# 1        0.132540   95.256400   0.640600     3.000000    7.0     1.0    10.0
# 2        0.053462  108.157619   0.101700     2.428571    9.0     1.0    42.0
# 3        0.035400  100.109000   0.165000     3.000000    5.0     1.0     2.0
# 4        0.036000   93.718667   0.220000     1.333333    3.0     1.0     6.0
# 5        0.053462  108.157619   0.101700     2.428571    9.0     1.0    42.0
# 6        0.060380  115.056600   0.287200     1.600000    7.0     1.0     5.0
# 7        0.041968   95.200198   0.264284     4.332090    2.0     1.0   268.0
# 8        0.121051  106.514583   0.638670     0.031847    5.0     1.0  1256.0
# 9        0.151787  103.368375   0.654875     0.000000   10.0     1.0    16.0
# 10       0.150501  100.642488   0.720334     2.440476    2.0     1.0    84.0
# 11       0.121051  106.514583   0.638670     0.031847    5.0     1.0  1256.0
# 12       0.054600  174.532000   0.493000     0.000000    5.0     0.0     2.0
# 13       0.040900  125.684786   0.452214     0.071429   11.0     0.0    28.0
# 14       0.032600  159.935000   0.493000     0.000000    7.0     1.0     2.0
# 15            NaN         NaN        NaN          NaN    NaN     NaN     NaN
# 16       0.036000   93.718667   0.220000     1.333333    3.0     1.0     6.0
# 17            NaN         NaN        NaN          NaN    NaN     NaN     NaN
# 18       0.040750  100.171333   0.261450     0.000000   11.0     1.0    12.0
# 19       0.074320  121.787000   0.337200     0.000000    3.0     1.0    10.0
#
# [20 rows x 34 columns]

# %%
# Create dataframe with only necesary columns
year_df = merge_genre[["year","name","artists","popularity_x","genres"]]

# %%
year_df.head()
# Out:
#    year                                               name  \
# 0  1921  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1  1921                            Clancy Lowered the Boom
# 2  1921                                          Gati Bali
# 3  1921                                          Danny Boy
# 4  1921                        When Irish Eyes Are Smiling
#
#                                              artists  popularity_x genres
# 0  Sergei Rachmaninoff, James Levine, Berliner Ph...             4    NaN
# 1                                         Dennis Day             5     []
# 2  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...             5     []
# 3                                       Frank Parker             3     []
# 4                                         Phil Regan             2     []

# %%
#group by & find the max

# %%
#groupby years
max_popularity = year_df.groupby(["year"])["popularity_x"].max()
max_popularity = max_popularity.reset_index()

popular_by_year = max_popularity.merge(year_df,on=["year","popularity_x"],how = "left")
popular_by_year
# Out:
#      year  popularity_x                                       name  \
# 0    1921             6                               Gati Mardika
# 1    1922             6                                      Carve
# 2    1923            42                               Weather Bird
# 3    1923            42  Nobody Knows You When You're Down and Out
# 4    1924            13    Mississippi Mud (feat. Bix Beiderbecke)
# ..    ...           ...                                        ...
# 109  2017            87                                   Believer
# 110  2018            89                               Lucid Dreams
# 111  2018            89                       lovely (with Khalid)
# 112  2019            94                           Watermelon Sugar
# 113  2020           100                                     Dakiti
#
#                                                artists  \
# 0    KHP Kridhamardawa Karaton Ngayogyakarta Hadini...
# 1                                                  Uli
# 2                          Louis Armstrong, Earl Hines
# 3                                         Bessie Smith
# 4       Paul Whiteman & His Orchestra, Bix Beiderbecke
# ..                                                 ...
# 109                                    Imagine Dragons
# 110                                         Juice WRLD
# 111                              Billie Eilish, Khalid
# 112                                       Harry Styles
# 113                             Bad Bunny, Jhay Cortez
#
#                                                 genres
# 0                                                   []
# 1    ['corrido', 'nuevo regional mexicano', 'region...
# 2                                                  NaN
# 3    ['blues', 'harlem renaissance', 'jazz blues', ...
# 4                                                  NaN
# ..                                                 ...
# 109                     ['modern rock', 'pop', 'rock']
# 110                     ['chicago rap', 'melodic rap']
# 111                                                NaN
# 112                           ['pop', 'post-teen pop']
# 113                                                NaN
#
# [114 rows x 5 columns]

# %%
#use loc function to find the top ten in each decate
decade_1 = year_df.loc[(year_df["year"]>=1921)&(year_df["year"]<=1930)]
top_ten_1 = decade_1.sort_values("popularity_x",ascending = False)
top_ten_1 = top_ten_1.head(10)
top_ten_1
# Out:
#       year                                               name  \
# 1606  1930                                   Monster Faladoré
# 1406  1929                                     Mack the Knife
# 1206  1928                                   Sing, Sing, Sing
# 806   1926                                  Ain't Misbehavin'
# 1607  1930  Hungarian Rhapsody No. 2 in C-Sharp Minor, S. ...
# 1207  1928            Dark Was the Night, Cold Was the Ground
# 807   1926                                  Two Sleepy People
# 222   1923          Nobody Knows You When You're Down and Out
# 1208  1928                       It's Nobody's Fault but Mine
# 221   1923                                       Weather Bird
#
#                              artists  popularity_x  \
# 1606                      Joe Quartz            55
# 1406                 Louis Armstrong            52
# 1206                   Benny Goodman            51
# 806                      Fats Waller            49
# 1607  Franz Liszt, Vladimir Horowitz            48
# 1207            Blind Willie Johnson            47
# 807                      Fats Waller            45
# 222                     Bessie Smith            42
# 1208            Blind Willie Johnson            42
# 221      Louis Armstrong, Earl Hines            42
#
#                                                  genres
# 1606                                                 []
# 1406  ['adult standards', 'dixieland', 'harlem renai...
# 1206  ['adult standards', 'bebop', 'big band', 'jazz...
# 806   ['adult standards', 'bebop', 'dixieland', 'har...
# 1607                                                NaN
# 1207  ['acoustic blues', 'appalachian folk', 'blues'...
# 807   ['adult standards', 'bebop', 'dixieland', 'har...
# 222   ['blues', 'harlem renaissance', 'jazz blues', ...
# 1208  ['acoustic blues', 'appalachian folk', 'blues'...
# 221                                                 NaN

# %%
decade_2 = year_df.loc[(year_df["year"]>=1931)&(year_df["year"]<=1940)]
top_ten_2 = decade_2.sort_values("popularity_x",ascending = False)
top_ten_2 = top_ten_2.head(10)
top_ten_2
# Out:
#       year                                               name  \
# 2206  1933     All of Me (with Eddie Heywood & His Orchestra)
# 3406  1939                        It's Been a Long, Long Time
# 3407  1939                                 Moonlight Serenade
# 3006  1937                                   Cross Road Blues
# 2208  1933                                        Tea for Two
# 3551  1939                                 In the Mood - Live
# 2209  1933  Gloomy Sunday (with Teddy Wilson & His Orchest...
# 2210  1933                                         Summertime
# 3409  1939                     Where Did You Sleep Last Night
# 3408  1939                                        In the Mood
#
#                             artists  popularity_x  \
# 2206  Billie Holiday, Eddie Heywood            64
# 3406                    Harry James            60
# 3407                   Glenn Miller            54
# 3006                 Robert Johnson            54
# 2208                      Art Tatum            53
# 3551                   Glenn Miller            52
# 2209   Billie Holiday, Teddy Wilson            52
# 2210                 Billie Holiday            52
# 3409                     Lead Belly            52
# 3408                   Glenn Miller            51
#
#                                                  genres
# 2206                                                NaN
# 3406  ['adult standards', 'big band', 'jazz trumpet'...
# 3407  ['adult standards', 'big band', 'easy listenin...
# 3006  ['acoustic blues', 'blues', 'blues rock', 'del...
# 2208  ['bebop', 'big band', 'contemporary post-bop',...
# 3551  ['adult standards', 'big band', 'easy listenin...
# 2209                                                NaN
# 2210  ['adult standards', 'harlem renaissance', 'jaz...
# 3409  ['acoustic blues', 'appalachian folk', 'blues'...
# 3408  ['adult standards', 'big band', 'easy listenin...

# %%
decade_3 = year_df.loc[(year_df["year"]>=1941)&(year_df["year"]<=1950)]
top_ten_3 = decade_3.sort_values("popularity_x",ascending = False)
top_ten_3 = top_ten_3.head(10)
top_ten_3
# Out:
#       year                                               name  \
# 4006  1942                                    White Christmas
# 4607  1945              It's Beginning To Look Like Christmas
# 5006  1947  Here Comes Santa Claus (Right Down Santa Claus...
# 4406  1944             Have Yourself A Merry Little Christmas
# 4606  1945                  Mele Kalikimaka (Merry Christmas)
# 5407  1949                                   Gymnopédie No. 1
# 4608  1945                         I'll Be Home For Christmas
# 4609  1945                        God Rest Ye Merry Gentlemen
# 5406  1949                           Twelve Days Of Christmas
# 5206  1948  Whatever Will Be, Will Be (Que Sera, Sera) (wi...
#
#                                                 artists  popularity_x  \
# 4006  Bing Crosby, Ken Darby Singers, John Scott Tro...            76
# 4607                                        Bing Crosby            71
# 5006                                         Gene Autry            70
# 4406                                       Judy Garland            70
# 4606                   Bing Crosby, The Andrews Sisters            69
# 5407                     Erik Satie, Philippe Entremont            67
# 4608                                        Bing Crosby            66
# 4609                                        Bing Crosby            64
# 5406                   Bing Crosby, The Andrews Sisters            64
# 5206             Doris Day, Frank DeVol & His Orchestra            62
#
#                                                  genres
# 4006                                                NaN
# 4607              ['adult standards', 'easy listening']
# 5006  ['adult standards', 'cowboy western', 'oklahom...
# 4406  ['adult standards', 'hollywood', 'lounge', 'to...
# 4606                                                NaN
# 5407                                                NaN
# 4608              ['adult standards', 'easy listening']
# 4609              ['adult standards', 'easy listening']
# 5406                                                NaN
# 5206                                                NaN

# %%
decade_4 = year_df.loc[(year_df["year"]>=1951)&(year_df["year"]<=1960)]
top_ten_4 = decade_4.sort_values("popularity_x",ascending = False)
top_ten_4 = top_ten_4.head(10)
top_ten_4
# Out:
#       year                                         name  \
# 7406  1959       Let It Snow! Let It Snow! Let It Snow!
# 7606  1960                                      At Last
# 7409  1959                              Johnny B. Goode
# 7006  1957                               Blue Christmas
# 7207  1958                               Jailhouse Rock
# 7007  1957  Dream A Little Dream Of Me - Single Version
# 7411  1959               Rudolph The Red-Nosed Reindeer
# 7206  1958                Come Fly With Me - Remastered
# 7607  1960                        A Sunday Kind Of Love
# 7608  1960                                  Sleigh Ride
#
#                                artists  popularity_x  \
# 7406                       Dean Martin            81
# 7606                        Etta James            76
# 7409                       Chuck Berry            75
# 7006                     Elvis Presley            74
# 7207                     Elvis Presley            73
# 7007  Ella Fitzgerald, Louis Armstrong            72
# 7411                       Dean Martin            70
# 7206                     Frank Sinatra            70
# 7607                        Etta James            70
# 7608                   Ella Fitzgerald            69
#
#                                                  genres
# 7406  ['adult standards', 'easy listening', 'lounge'...
# 7606  ['adult standards', 'jazz blues', 'soul', 'sou...
# 7409  ['blues rock', 'classic rock', 'rock', 'rock-a...
# 7006                    ['rock-and-roll', 'rockabilly']
# 7207                    ['rock-and-roll', 'rockabilly']
# 7007                                                NaN
# 7411  ['adult standards', 'easy listening', 'lounge'...
# 7206    ['adult standards', 'easy listening', 'lounge']
# 7607  ['adult standards', 'jazz blues', 'soul', 'sou...
# 7608  ['adult standards', 'jazz blues', 'swing', 'vo...

# %%
decade_5 = year_df.loc[(year_df["year"]>=1961)&(year_df["year"]<=1970)]
top_ten_5 = decade_5.sort_values("popularity_x",ascending = False)
top_ten_5 = top_ten_5.head(10)
top_ten_5
# Out:
#       year                                      name  \
# 8406  1964         Rockin' Around The Christmas Tree
# 8206  1963  It's the Most Wonderful Time of the Year
# 9407  1969      Here Comes The Sun - Remastered 2009
# 9406  1969                             Fortunate Son
# 9007  1967             Ain't No Mountain High Enough
# 8207  1963                               Sleigh Ride
# 8606  1965                                   My Girl
# 9006  1967                           Brown Eyed Girl
# 9410  1969           Come Together - Remastered 2009
# 8806  1966      California Dreamin' - Single Version
#
#                            artists  popularity_x  \
# 8406                    Brenda Lee            85
# 8206                 Andy Williams            83
# 9407                   The Beatles            82
# 9406  Creedence Clearwater Revival            81
# 9007    Marvin Gaye, Tammi Terrell            80
# 8207                  The Ronettes            80
# 8606               The Temptations            79
# 9006                  Van Morrison            79
# 9410                   The Beatles            79
# 8806         The Mamas & The Papas            79
#
#                                                  genres
# 8406          ['adult standards', 'brill building pop']
# 8206  ['adult standards', 'brill building pop', 'eas...
# 9407  ['beatlesque', 'british invasion', 'classic ro...
# 9406  ['album rock', 'classic rock', 'country rock',...
# 9007                                                NaN
# 8207  ['brill building pop', 'classic girl group', '...
# 8606  ['brill building pop', 'classic soul', 'funk',...
# 9006  ['classic rock', 'folk', 'folk rock', 'mellow ...
# 9410  ['beatlesque', 'british invasion', 'classic ro...
# 8806  ['brill building pop', 'bubblegum pop', 'class...

# %%
decade_6 = year_df.loc[(year_df["year"]>=1971)&(year_df["year"]<=1980)]
top_ten_6 = decade_6.sort_values("popularity_x",ascending = False)
top_ten_6 = top_ten_6.head(10)
top_ten_6
# Out:
#        year                                               name  \
# 11006  1977                             Dreams - 2004 Remaster
# 11606  1980                                      Back In Black
# 11406  1979                                    Highway to Hell
# 10806  1976                   Hotel California - 2013 Remaster
# 10406  1974                                 Sweet Home Alabama
# 11007  1977                          The Chain - 2004 Remaster
# 10006  1972  Rocket Man (I Think It's Going To Be A Long, L...
# 11008  1977                                       Mr. Blue Sky
# 10606  1975                                          Landslide
# 11610  1980                        You Shook Me All Night Long
#
#                         artists  popularity_x  \
# 11006             Fleetwood Mac            89
# 11606                     AC/DC            84
# 11406                     AC/DC            84
# 10806                    Eagles            83
# 10406            Lynyrd Skynyrd            82
# 11007             Fleetwood Mac            82
# 10006                Elton John            82
# 11008  Electric Light Orchestra            81
# 10606             Fleetwood Mac            80
# 11610                     AC/DC            80
#
#                                                   genres
# 11006  ['album rock', 'classic rock', 'mellow gold', ...
# 11606  ['album rock', 'australian rock', 'hard rock',...
# 11406  ['album rock', 'australian rock', 'hard rock',...
# 10806  ['album rock', 'classic rock', 'country rock',...
# 10406  ['album rock', 'blues rock', 'classic rock', '...
# 11007  ['album rock', 'classic rock', 'mellow gold', ...
# 10006  ['glam rock', 'mellow gold', 'piano rock', 'so...
# 11008  ['album rock', 'art rock', 'beatlesque', 'bow ...
# 10606  ['album rock', 'classic rock', 'mellow gold', ...
# 11610  ['album rock', 'australian rock', 'hard rock',...

# %%
decade_7 = year_df.loc[(year_df["year"]>=1981)&(year_df["year"]<=1990)]
top_ten_7 = decade_7.sort_values("popularity_x",ascending = False)
top_ten_7 = top_ten_7.head(10)
top_ten_7
# Out:
#        year                                          name  \
# 12208  1983                         Every Breath You Take
# 12607  1985                                    Take on Me
# 12007  1982                                   Billie Jean
# 13606  1990                                 Thunderstruck
# 12806  1986                            Livin' On A Prayer
# 12006  1982                                        Africa
# 12406  1984                                 Summer Of '69
# 12606  1985             Everybody Wants To Rule The World
# 13006  1987    I Wanna Dance with Somebody (Who Loves Me)
# 12206  1983  Sweet Dreams (Are Made of This) - Remastered
#
#                                       artists  popularity_x  \
# 12208                              The Police            84
# 12607                                    a-ha            84
# 12007                         Michael Jackson            83
# 13606                                   AC/DC            83
# 12806                                Bon Jovi            83
# 12006                                    TOTO            83
# 12406                             Bryan Adams            82
# 12606                         Tears For Fears            82
# 13006                         Whitney Houston            82
# 12206  Eurythmics, Annie Lennox, Dave Stewart            81
#
#                                                   genres
# 12208  ['album rock', 'art rock', 'classic rock', 'da...
# 12607  ['album rock', 'classic rock', 'folk rock', 'm...
# 12007                             ['pop', 'r&b', 'soul']
# 13606  ['album rock', 'australian rock', 'hard rock',...
# 12806                             ['glam metal', 'rock']
# 12006  ['album rock', 'classic rock', 'mellow gold', ...
# 12406  ['album rock', 'canadian pop', 'canadian singe...
# 12606  ['dance rock', 'new romantic', 'new wave', 'ne...
# 13006         ['dance pop', 'pop', 'urban contemporary']
# 12206                                                NaN

# %%
decade_8 = year_df.loc[(year_df["year"]>=1991)&(year_df["year"]<=2000)]
top_ten_8 = decade_8.sort_values("popularity_x",ascending = False)
top_ten_8 = top_ten_8.head(10)
top_ten_8
# Out:
#        year                             name                artists  \
# 14406  1994  All I Want for Christmas Is You           Mariah Carey
# 15608  2000                       In the End            Linkin Park
# 15606  2000                           Yellow               Coldplay
# 14006  1992                 Jingle Bell Rock            Bobby Helms
# 13812  1991               Losing My Religion                 R.E.M.
# 14206  1993                            Creep              Radiohead
# 14607  1995               Gangsta's Paradise           Coolio, L.V.
# 15410  1999                  Californication  Red Hot Chili Peppers
# 13808  1991                 Under the Bridge  Red Hot Chili Peppers
# 14410  1994                           Zombie        The Cranberries
#
#        popularity_x                                             genres
# 14406            88  ['dance pop', 'pop', 'r&b', 'urban contemporary']
# 15608            84  ['alternative metal', 'nu metal', 'post-grunge...
# 15606            84                          ['permanent wave', 'pop']
# 14006            83                                                 []
# 13812            82  ['alternative rock', 'classic rock', 'permanen...
# 14206            82  ['alternative rock', 'art rock', 'melancholia'...
# 14607            82                                                NaN
# 15410            81  ['alternative rock', 'funk metal', 'funk rock'...
# 13808            81  ['alternative rock', 'funk metal', 'funk rock'...
# 14410            81                         ['irish rock', 'pop rock']

# %%
decade_9 = year_df.loc[(year_df["year"]>=2001)&(year_df["year"]<2010)]
top_ten_9 = decade_9.sort_values("popularity_x",ascending = False)
top_ten_9 = top_ten_9.head(10)
top_ten_9
# Out:
#        year                                name                   artists  \
# 16006  2002                    'Till I Collapse         Eminem, Nate Dogg
# 16009  2002                       The Scientist                  Coldplay
# 17207  2008                           I'm Yours                Jason Mraz
# 16806  2006         Last Christmas - Remastered                     Wham!
# 16008  2002                          Without Me                    Eminem
# 16611  2005  Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
# 16839  2006                         Promiscuous  Nelly Furtado, Timbaland
# 16616  2005                             Fix You                  Coldplay
# 16407  2004    Yeah! (feat. Lil Jon & Ludacris)  Usher, Lil Jon, Ludacris
# 16206  2003                                Numb               Linkin Park
#
#        popularity_x                                             genres
# 16006            84                                                NaN
# 16009            84                          ['permanent wave', 'pop']
# 17207            83  ['acoustic pop', 'neo mellow', 'pop', 'pop rock']
# 16806            83  ['dance pop', 'dance rock', 'disco', 'europop'...
# 16008            83              ['detroit hip hop', 'hip hop', 'rap']
# 16611            83                                                NaN
# 16839            82                                                NaN
# 16616            82                          ['permanent wave', 'pop']
# 16407            82                                                NaN
# 16206            82  ['alternative metal', 'nu metal', 'post-grunge...

# %%
decade_10 = year_df.loc[(year_df["year"]>=2011)&(year_df["year"]<2020)]
top_ten_10 = decade_10.sort_values("popularity_x",ascending = False)
top_ten_10 = top_ten_10.head(10)
top_ten_10
# Out:
#        year                  name                artists  popularity_x  \
# 19407  2019      Watermelon Sugar           Harry Styles            94
# 19426  2019           Breaking Me             Topic, A7S            92
# 19413  2019     Someone You Loved          Lewis Capaldi            91
# 19406  2019                 Sofia                 Clairo            90
# 19443  2019              Memories               Maroon 5            89
# 19207  2018          Lucid Dreams             Juice WRLD            89
# 19210  2018  lovely (with Khalid)  Billie Eilish, Khalid            89
# 19441  2019          Dance Monkey            Tones And I            89
# 19417  2019                Golden           Harry Styles            89
# 19409  2019               Circles            Post Malone            89
#
#                                   genres
# 19407           ['pop', 'post-teen pop']
# 19426                                NaN
# 19413                  ['pop', 'uk pop']
# 19406    ['bedroom pop', 'boston indie']
# 19443                ['pop', 'pop rock']
# 19207     ['chicago rap', 'melodic rap']
# 19210                                NaN
# 19441                 ['australian pop']
# 19417           ['pop', 'post-teen pop']
# 19409  ['dfw rap', 'melodic rap', 'rap']

# %%
import statistics 
from statistics import mode, StatisticsError #using this to find the most frequently occuring single word & catch related exceptions
selectedGenre = []
#to call function, enter the data frame you want to use as input and it will return a new data frame as output
def genreFinder(sourceDataFrame):
    #remove unwanted characters & don't show index; each track is on a new line -- split by new line
    trackList = sourceDataFrame["genres"].to_string(index=False).replace("[", "").replace("]", "").replace("'", "").replace(",", "").split("\n")
    for genre in trackList:   
        genreWords = genre.strip().split(" ") #strip leading and trailing whitespace and split different genres based on space as delimiter
        try:
            mostCommonWord = mode(genreWords)
        except StatisticsError:
            mostCommonWord = "Eclectic"
        selectedGenre.append(mostCommonWord)
    outputDataFrame = sourceDataFrame.copy() #making a copy of the source data frame to be used as the new data frame
    outputDataFrame["genre"] = selectedGenre #creating "genre" column in new output data frame and setting value equal to list of most frequently occuring genre word
    return outputDataFrame

genre_df10 = genreFinder(top_ten_10)
genre_df10
# output_path = os.path.join("Resources", "genre_decade_10.csv")
# genre_df10.to_csv(output_path, sep=',')#write the data frame to a CSV
# Out:
#        year                  name                artists  popularity_x  \
# 19407  2019      Watermelon Sugar           Harry Styles            94
# 19426  2019           Breaking Me             Topic, A7S            92
# 19413  2019     Someone You Loved          Lewis Capaldi            91
# 19406  2019                 Sofia                 Clairo            90
# 19443  2019              Memories               Maroon 5            89
# 19207  2018          Lucid Dreams             Juice WRLD            89
# 19210  2018  lovely (with Khalid)  Billie Eilish, Khalid            89
# 19441  2019          Dance Monkey            Tones And I            89
# 19417  2019                Golden           Harry Styles            89
# 19409  2019               Circles            Post Malone            89
#
#                                   genres     genre
# 19407           ['pop', 'post-teen pop']       pop
# 19426                                NaN       NaN
# 19413                  ['pop', 'uk pop']       pop
# 19406    ['bedroom pop', 'boston indie']  Eclectic
# 19443                ['pop', 'pop rock']       pop
# 19207     ['chicago rap', 'melodic rap']       rap
# 19210                                NaN       NaN
# 19441                 ['australian pop']  Eclectic
# 19417           ['pop', 'post-teen pop']       pop
# 19409  ['dfw rap', 'melodic rap', 'rap']       rap
